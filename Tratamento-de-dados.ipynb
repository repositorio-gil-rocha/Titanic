# %%
# importando as blibs
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Importando os dados
df_teste = pd.read_csv('test.csv')
df_treino = pd.read_csv('train.csv')
df_submission = pd.read_csv('gender_submission.csv')

# %%
print('df_teste',df_teste.shape)
print('df_treino',df_treino.shape)
print('df_submission',df_submission.shape)
# Out:
# df_teste (418, 11)
# df_treino (891, 12)
# df_submission (418, 2)

# %%
df_teste.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df_treino.head(80)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 75           76         0       3
# 76           77         0       3
# 77           78         0       3
# 78           79         1       2
# 79           80         1       3
#
#                                                  Name  Sex    Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    0  22.00      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.00      1
# 2                              Heikkinen, Miss. Laina    1  26.00      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.00      1
# 4                            Allen, Mr. William Henry    0  35.00      0
# ..                                                ...  ...    ...    ...
# ...

# %%
# Verificando os dados ausentes
df_treino.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Contagem do número de sobreviventes
# 0 = não Sobreviveu
# 1 = Sobreviveu



plt.figure(figsize=(6,2))
sns.countplot(data=df_treino, x='Pclass')
print("\n")
df_treino['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# Comecando as análises pelo df_teste

# %%
# Verificando a quantidade de classes existentes
df_treino['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# imprimindo um Gráfico

plt.figure(figsize=(6,2))
sns.countplot(data=df_treino, x='Pclass')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
# Visualização dos dados Classe vs Sobrevivencia
# Podemos ver que o maior número de mortes estão na 3ª Classe.

plt.figure(figsize=(8,2))
sns.countplot(x='Pclass', hue='Survived',  data=df_treino)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
## Coluna Sex

# %%
df_treino['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
# Alterando o Sexo para valores númericos
df_treino['Sex'] = df_treino['Sex'].replace(['male','female'],[0, 1])

df_treino['Sex'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-ef56ce013870> in <module>
#       1 # Alterando o Sexo para valores númericos
# ----> 2 df_treino['Sex'] = df_treino['Sex'].replace(['male','female'],[0, 1])
#       3
#       4 df_treino['Sex'].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4561         method="pad",
#    4562     ):
# -> 4563         return super().replace(
#    4564             to_replace=to_replace,
#    4565             value=value,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6541                         )
#    6542                     self._consolidate_inplace()
# -> 6543                     new_data = self._mgr.replace_list(
# ...

# %%
plt.figure(figsize=(6,3))
sns.countplot(data=df_treino, x='Sex')
